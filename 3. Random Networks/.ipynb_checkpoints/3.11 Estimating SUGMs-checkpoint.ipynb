# %% [markdown]
# #  SUGMs
#
# - Nature/people form Sj subnetworks of type j each independently with probability pj
# - May intersect and overlap
# - Weobserveresultingnetwork, infer the $p_j’s$

# %% [markdown]
# ## Estimation - Two Approaches
# - Sparse graphs: rare incidentals, Direct estimation is valid / consistent
# - Algorithm: corrects for small n, and provides estimates for non-sparse (see CJ paper)

# %% [markdown]
# ## Sparseness
# - Incidentals generated by combinations of other subgraphs
# - Sparsity definition relates rates of all subgraphs to each other (none grow too quickly)
# - Intutive example: links and triangles
#  - $p_L = O(n^{-1/2})$, $p_T = O(n^{-3/2})$
#  - Typical node involved in less than $n^{1/2}$ links, $n^{1/2}$ triangles

# %% [markdown]
# # Links Form: Incidental Triangle
#
# ![](https://lh3.googleusercontent.com/9z_JXeTz4wqcUEDuTPawCkxQekgG28D_SUfSdkd6rqCu2on7juyWVQpN_uKCKtIkzqDaqvjlPb87EXSZ3fGEUEWSDQF1mSpUTc0kB5MRWK2OZAZOFOQXocLv1KtFK_vXELH02H3BD0UirNVsN5KCYx9FjqJuWRXJRZohdgFAwxOfxRSLT0oshs5cRZQytXhEngnzW3aSx6VFinMW4_weSGhc1CSOKfb9TJDF94Ieji5PNBErcMmtI0ckDaR_t8zWP0_DSHSU7bbMTDecd_pz0ZrtO9U79fDnp4uEFoexaTaX_0hieR9UTD8cKaZvmjpnNNSkV1R9DMYEUcXQDsX47RWP2voCstr7q7dvfVX9maJcuiSgIVRbnAij3Mx3AoPM0bEgJqfk-OwOE26malumq1Rd4G2fjaCSnKhWPJsDxymX-M4F7ZglthvtPJ1dqf4WqGf6hKtAGq6FMmxwQ3TtcCg9j05NOjMaEhQrKdDWasoZEBKY8IgYyZRksxxgMShoWLskiCYY6YwGCKaIc2utaLbHYCNQLMgp92vpx38UTm2XfIXzpqm_-FGGKK2ns_4t9QZM0wq8VzPTezPP1_tbMfmeDBeWhOhSMC8whiNcj10uRCTPxbMzVoN-LQo4AhGLR14_VhmTpy8G23Uq5PhDTlmqupbAUmCRGuWp27EtwBSHfbopmDexlRLb=w471-h334-no)
#
# # Estimation
#
# ![](https://lh3.googleusercontent.com/8laLMUOXvx76ixbYvmZNhWjw48iIsNsUhKcP4lSYlXOfwxEeuRt_Z5aRjGiCKgZV_8vSSgJ53TpgILCgHSJPesJXuliNN9MpKaOprnbkyea96HxXhjqLYg8mrwr49Jk40oYAgC-eXoiq5vLgE6tLSpEzCTlzF0TwRToQWvXmVGoa5wKS6KBfNtaRJCGlgOwFPrKUUjL6EdQVkzciBSKHLWRhmkIR8k5yCyGTUm11Equ8sYpbW55EvqTAYZDfgZM6WL7Y3NLRLLRo4fcvTMcOT2Q_fW6GBdf-3mrMY7QVnzCOW2gyRbk6-xwRiKrwefV9iJVO_gxlQsEt-Y677Gv1QWzxareOmOhLkmvLan2AKQID9gLfn8EwlvJmHD7pByGD9Li9T8Cwcz2o8vLUMKhrZWadV0rLv4kgxJe5fkT5c_UqcWtcaMSuGCTOZfZFPuZg-8VEnMAeA0G8rMoE
# %% [markdown]
# ## Theorem: Consistency and Distribution
#
# Consider a sequence of sparse SUGMs
#
# $S$: how many did you actually observe
#
# $\bar s$: how many could there have been
#
# The empirical frequency $\hat p^n_j = S^n_j / \bar S^n_j$ is (ratio) consistent:
#
# $\hat p^n_j / p^n_j -> 1$ and $ D^{1/2}(\hat p^n - p^n) -> N(0, 1)$

# %% [markdown]
# ## Need for SERGMs/SUGMs:
# - Examine data from 75 Indian villages from BCDJ '13
# - How well do the model-recreated networks match real networks on **non-modeled characteristics**
# - Estimate SUGM based on covariates, allowing for triangle counts
# - Estimate standard link-based (block) model based on covariates
# - Does SUGM do better than block model at recreating networks?
# - Block model
#  - prob of a link of both of the same category or similar to each other
#  - prob of link if different
# - SUGM add in
#  - prob of triangle if all similar
#  - prob of triangle if some different
#
# ** block model is a special case of a SUGM where we just look at links**
#
# - Step 1: Estimate models
#  - Block model, estimate $p_{LinkSame}$ $p_{LinkDiff}$
#  - SUGM, estimate $p_{LinkSame}$ $p_{LinkDiff}$, $p_{TriadSame}$ $p_{TriadDiff}$
# - Step 2: randomly generate networks
#  - Block model - randomly generate links
#  - SUGM - randomly generate links, triangles...
# - Step 3: After generate networks, we can see whether or not these networks recreate the actual, original observations.

# %% [markdown]
# ![](https://lh3.googleusercontent.com/5LSf6A-UXAmrmAi1LuksoBdW8-flSh_K3n3FsTm4XoUEZAOWG81MTDD2W6-YzSO7g2deITCBcNQMSHxf3Z8oVBnlVxmDDu_Q1XPtMZ4nG_6eXhb_R2rTHceVJGh3U2JMVFBzHCiIMU5ftOb34YLAqA0rWavWFnRzp0U8bntfpsqweIgQhQFUYCacAKH-A4CoODnW8kB0-noEcVulJLnQvAm1WQq0be_KG66kT7xD_-fMVwQeveCt4j7HrEsSf2YCYT6NWt9WF7dg66cjcJU9hybGGa3HeT6Mn9u-VzQ1LaFQhniCPsgUuPIuGm1HHaw8-ToIrOaVy9s3qqGPaDRpl3e-U0H0l22zKxzMjxTy-LaibX4HlYI7Xjgvg5Q-orbqdm5ErHbaUMWkjxoKF4iYUSzYssWR7zc-DlIziMn71fPKufRe7Xv_Fc2gUnZ2qHmKXeYmZ38BXu7BbbePW502l0iB8_-iMnQgA121yhqaBZ0PbI87ZzWWDf1lhmw6eLpFqmHXtXLiJxiTZ_iX6PM_fwomttjyFvv_46EmKWHmcsUq1tRArU2a_IOnUqZExXWtC3D3XCUK-2Wmw1Y_UDNTEELt_AbpgdUy2pW6FMugJJ7jwL1V38MZXudZTG4RDWk4R98Y3jk48unNZ9Cxlu2H6qKK-omjF773GkDSGD3Dha9HsYJofZjAjzI_=w874-h623-no)
#
D1F2UKURAUwD0KYRrt7DGjj2iV1c1NIhhXmt66MEGowkiSsLkldiT0Yr6Rtycgni6PLCW0W4PUhDAeUQyOcBZMTotDPC1Q147pOm7vc4ObxVnOy4ZDHUxMXNEtImJqrMBevUwxtbYgwwK9ZYspZrInakULYokUqddhBeDN9D5_sedisKM9KFx38BJCwwSqO-5gEEUyZNyOwUToeC_OQHPKAKaKmFkH-9wlPszXC6pFM0QHmQTz707e9M4HRudoy6PqpRPq1QXKUcX_AYfjuBqq06Nm8OyIizTON2tqVcJJol-S7NUlc61F3Aoy-z3j0QA-KF1206FeBWURj1EoX6Xy0MZ-CZPv8iuAndUQsO0FLhABJZ-mPfcUeQMwM_WOIREJh_OXPatrw-aky-8a3aqJagQ=w970-h630-no)
#
# ![](https://lh3.googleusercontent.com/7i-LAuaW4exlJpwVgcGJ-33gasKNzos1cg8KHInVASPuaaqd2FpVDDHmsNzZOSe-DICPngExnIopB5KwUVsmyW0nmGvz0jH17ftT8lZUAUrYtUYNlpeFJI3oPufFtVtIs_U8Umi605ipeejuB6WmTcGiYl__fgP-HdtJ53uCfZBXlVEshbY_nwb_OTuPz1-cO2-H3GR7_dXW76fbIDcm6hXxySfCN5Ddi5whsNwBUfS21x2h4Oi_BaC7GGgbup50ONRtlxUrFYiaZUqwTOPm34WX2DiZqsPpNG19SUqcpfyzbcIKkEHyU-CIQWbHd525hcmpmO4VIKc2AxBWNqQFFg7841JTe0jIJgF8cdvsE2KYxXM6kn3kbR2UMxWjZqaAkoz8li7f3_L6m846bljM-baOeGbXcaETmMY5bQXREI5NsP1dblL6AczMmffT6buefeVW_bFDssPUHfwWtRjXhTSviN-BPjkbH5Ihg15OOPvHC1O7xi8QeEu8tfoAqVQFlrBRBkgmcwRDZQpr1K3pOYwTspggWejY58F0Mo1HhlBTK4x5xheeIXYSo_VIrg2wkLYrQwBhzMhUu_t1dC9lGwa-aW2ck4M1gGkuXCS1sZNh1i8sX4Kd4ElvjRUfJnTBDDbL0a5FW0iMKhXzNynFFqNWToRL7G7phdstsZW9ptohQjBoU88I6wx7=w957-h638-no)

# %% [markdown]
# ## Dependencies
# Dependencies are really important to pick up in social networks. Why? well that's the whole nature of social
# - "Social" by definition generates dependencies
# - Need tractable models to capture / test these
# - ERGMs are rich family, but not always accurately estimable
# - SERGMs and SUGMs offer easy and consistent estimation.

# %% [markdown]
# ## Network Models
# - Statistical models offer a medium, but also need models *in context*
# - Understand dependencies? Friends of friends, social enforcement...
# - What should we be testing for?
# - Example, see lecture 4.9

# %% [markdown]
# ## Strengths Random Networks:
# - Generate large networks with well identified properties
# - Mimic real networks (at least in some characteristics)
# - **Tie specific properties to specify processes**

# %% [markdown]
# ## Weaknesses of Random Network Models
# - Missing the "Why"
#  - Why this process?(lattice, preferential attach...)
# - Missing implications of networks structure: context or relevance
#  - welfare, efficiency?
# - Literature is missing careful empirical analysis of many "stylized facts" (small worlds, power laws, clustering...)
#  - ERGMs have filling that niche, but need estimable models
#  - New models are emerging
